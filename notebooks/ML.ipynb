# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("../data/MS_GSE21942.csv")

# %%
df.head()
# Out:
#    BOD1L1  IFI27  MALAT1  HBG2   LTF  HBG2.1   HBG1  SAMSN1  MALAT1.1  \
# 0     9.1    6.7   372.7  13.9  12.9    36.7   42.2     8.5      58.8
# 1    10.4  103.7   604.7  87.7  11.5   100.4  103.7    50.2      89.1
# 2    15.1    6.5  1492.0  45.8   8.2    36.8   58.1    36.6      82.3
# 3     8.4    5.3   893.8  12.8  86.9     9.1   12.2    11.3      71.6
# 4    10.3    5.2   703.9  67.6   7.7    46.9   57.8    12.4      78.0
#
#    MALAT1.2  ...  EIF2S3  MOB3A  SNRNP40   MDM4  MAT2A  ZNF595  LAMP1  CLEC7A  \
# 0     130.4  ...   971.7  224.5    144.6  105.2  165.4    18.9  276.6   226.4
# 1     208.0  ...   726.2  155.6    106.1  105.2  146.7    36.3  185.8   448.3
# 2     250.0  ...  1046.2  129.7    126.0   60.8   98.3     9.3  228.0   301.0
# 3     165.6  ...   778.3  147.6    165.4   87.2  122.4    17.2  200.8   209.4
# 4     194.0  ...   814.1  140.3    149.6   72.4  134.3   116.5  223.9   256.1
#
#    SERPINB9  Outcome
# 0      37.9        0
# 1      37.1        0
# 2      30.7        0
# 3      27.9        0
# 4      29.0        0
#
# [5 rows x 51 columns]

# %%
X = df.drop('Outcome', axis = 1)
y = df['Outcome']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=36)

# %%
X.shape, y.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((29, 50), (29,), (23, 50), (6, 50), (23,), (6,))

# %%
from sklearn.linear_model import LogisticRegression 
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test)
predictions
# Out:
# array([1, 0, 1, 1, 1, 0], dtype=int64)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[2, 0],
#        [0, 4]], dtype=int64)
